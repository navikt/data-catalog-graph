# %%
import pandas as pd
import pandas.io.sql as sqlio
import psycopg2
import sqlalchemy
import os
import json

from dotenv import load_dotenv
load_dotenv()

import matplotlib as plt
# %matplotlib inline

# %%
conn = psycopg2.connect(
    user=os.getenv("POSTGRES_USER"), 
    password=os.getenv("POSTGRES_PASSWORD"), 
    host="127.0.0.1", 
    port="54320", 
    database="dcat")

# %%
cur = conn.cursor()

# %%
print ( conn.get_dsn_parameters(),"\n")
# Out:
# {'user': 'dcat', 'dbname': 'dcat', 'host': '127.0.0.1', 'port': '54320', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}

# %%
cur.execute("SELECT version();")
record = cur.fetchone()
print("You are connected to - ", record,"\n")
# Out:
# You are connected to -  ('PostgreSQL 12.0 (Debian 12.0-1.pgdg100+1) on x86_64-pc-linux-gnu, compiled by gcc (Debian 8.3.0-6) 8.3.0, 64-bit',)

# %% [markdown]
# # Init

# %% [markdown]
# ### Relationship description/attributes

# %%
cur.execute("delete from tbl_er_desc")

# %% [markdown]
# ### Relationships/Edges

# %%
cur.execute("delete from tbl_er")

# %% [markdown]
# ### Node details table

# %%
cur.execute("delete from tbl_detail")

# %% [markdown]
# # Get data

# %%
xls = pd.ExcelFile("../data/testdata.xlsx")

# %%
xls.sheet_names
# Out:
# ['Formål GML',
#  'Formål',
#  'Ark1',
#  'data-catalog-backend',
#  'data-catalog-policies',
#  'Category']

# %%
conn.commit()

# %% [markdown]
# # Populate tables

# %% [markdown]
# ### Relationships

# %%
relationships = ["has purpose", "based on purpose", "has attribute", "attribute of"]
index = 1
for relationship in relationships:
    insert_query = f"insert into tbl_er_desc values ({index},'{relationship}')"
    cur.execute(insert_query)
    index += 1
    
conn.commit()

# %%
df = sqlio.read_sql_query("select * from tbl_er_desc limit 2", conn)
df
# Out:
#    id              info
# 0   1       has purpose
# 1   2  based on purpose

# %% [markdown]
# ### Processing activities

# %%
sheet=xls.sheet_names[1]
df_formål = pd.read_excel(xls, sheet, encoding='latin1')
df_formål = df_formål[['Forslag til endelig formålskode', 'Formålsbeskrivelse']]
df_formål.columns=['code', 'description']
df_formål['name'] = df_formål['code'].apply(lambda x: x.upper())
df_formål = df_formål.append({'name': 'NOT AVAILABLE', 'description': 'Not Available -Verdi mangler'}, ignore_index=True)
df_formål.drop(['code'], axis=1, inplace=True)
df_formål['type'] = 'prosessing activity'
df_formål.tail()
# Out:
#                                           description  \
# 33  Behandle og vurdere rett til uføretrygd som sk...
# 34  Behandle og vurdere rett til ventelønn som ska...
# 35  Behandle og vurdere rett til ytelser ved yrkes...
# 36  Behandle og vurdere rett til ytelser til famil...
# 37                       Not Available -Verdi mangler
#
#                          name                 type
# 33                 UFØRETRYGD  prosessing activity
# 34                  VENTELØNN  prosessing activity
# 35      YRKESSKADE- OG SYKDOM  prosessing activity
# 36  YTELSER TIL FAMILIEPLEIER  prosessing activity
# 37              NOT AVAILABLE  prosessing activity

# %%
for index, row in df_formål.iterrows():
    id = index + 1
    jsonb = row.to_json()
    insert_query = f"insert into tbl_detail values ({id},'{jsonb}', now())"
    cur.execute(insert_query, (jsonb,))
    
conn.commit()

# %% [markdown]
# ### Legal basis

# %%
sheet=xls.sheet_names[4]

cur.execute("select max(id) from tbl_detail")
index = cur.fetchone()[0]

df = pd.read_excel(xls, sheet, encoding='latin1')
legal_basis_list = df['legalBasisDescription'].unique()
for legal_basis in legal_basis_list:
    index = index + 1
    jsonb = json.dumps('{"name":' + legal_basis + ', "type": "legal_basis"}')
    insert_query = f"insert into tbl_detail values ({index},'{jsonb}', now())"
    cur.execute(insert_query, (index, jsonb,))
    
conn.commit()

# %% [markdown]
# ### Attributes

# %%
sheet=xls.sheet_names[3]

cur.execute("select max(id) from tbl_detail")
index = cur.fetchone()[0]

df_attributes = pd.read_excel(xls, sheet, encoding='latin1')
df_attributes = df_attributes[['title', 'description']]
df_attributes.columns=['name', 'description']
df_attributes = df_attributes.append({'name': 'NOT AVAILABLE', 'description': 'Not Available -Verdi mangler'}, ignore_index=True)
df_attributes['type'] = 'attribute'
df_attributes.head()
# Out:
#              name                                        description  \
# 0      Sivilstand  En overordnet kategori som beskriver en person...
# 1  Arbeidsforhold  Avtaleforhold hvor den ene part, arbeidstakere...
# 2           Kjønn  TODO - mangler i begrepskatalogen og i MFNs be...
# 3            Navn  I Norge skal alle ha fornavn og ett enkelt ell...
# 4    Fødselsdato                            Datoen personen er født.
#
#         type
# 0  attribute
# 1  attribute
# 2  attribute
# 3  attribute
# 4  attribute

# %%
for i, row in df_attributes.iterrows():
    index = index + 1
    jsonb = row.to_json()
    insert_query = f"insert into tbl_detail values ({index},'{jsonb}', now())"
    cur.execute(insert_query, (jsonb,))
    
conn.commit()

# %% [markdown]
# ### test

# %%
df = sqlio.read_sql_query("select * from tbl_detail", conn)
df.tail()
# Out:
#       id                                               info  \
# 214  215  {'name': 'Flyktningstatus ', 'type': 'attribut...
# 215  216  {'name': 'Foreldreansvar', 'type': 'attribute'...
# 216  217  {'name': 'Forsterforeldre ', 'type': 'attribut...
# 217  218  {'name': 'Fullmakt ', 'type': 'attribute', 'de...
# 218  219  {'name': 'NOT AVAILABLE', 'type': 'attribute',...
#
#                       crt_time
# 214 2019-10-07 17:45:40.436798
# 215 2019-10-07 17:45:40.436798
# 216 2019-10-07 17:45:40.436798
# 217 2019-10-07 17:45:40.436798
# 218 2019-10-07 17:45:40.436798

# %% [markdown]
# ### Edges

# %%
cur.execute("insert into tbl_er values (1,2,array[1],now());")
cur.execute("insert into tbl_er values (2,1,array[2],now());")
cur.execute("insert into tbl_er values (1,3,array[1],now());")
cur.execute("insert into tbl_er values (3,1,array[2],now());")
cur.execute("insert into tbl_er values (5,2,array[1],now());")
cur.execute("insert into tbl_er values (2,5,array[2],now());")
cur.execute("insert into tbl_er values (5,3,array[1],now());")
cur.execute("insert into tbl_er values (3,5,array[2],now());")
cur.execute("insert into tbl_er values (4,1,array[1],now());")
cur.execute("insert into tbl_er values (1,4,array[2],now());")
cur.execute("insert into tbl_er values (6,5,array[1],now());")
cur.execute("insert into tbl_er values (5,6,array[2],now());")
cur.execute("insert into tbl_er values (7,1,array[1],now());")
cur.execute("insert into tbl_er values (1,7,array[2],now());")
cur.execute("insert into tbl_er values (8,5,array[1],now());")
cur.execute("insert into tbl_er values (5,8,array[2],now());")

# %%
conn.commit()

# %%
sql = """
create or replace function graph_search1(      
  IN i_root int,                       -- The node that the search is based on        
  IN i_depth int  default 99999,       -- the tier to search (the depth limit)      
  IN i_limit int8 default 2000000000,  -- limit the number of records returned for each tier      
  OUT o_path int[],                    -- output: path, an array of IDs      
  OUT o_point1 int,                    -- output: point 1 ID      
  OUT o_point2 int,                    -- output: point 2 ID      
  OUT o_link_prop int2[],              -- output: the connection property between the two current points      
  OUT o_link_prop_all text,            -- output: the connection property from the starting node to the current node      
  OUT o_depth int                      -- output: current depth (tier)      
) returns setof record as 
$$
      
declare      
  sql text;      
begin      
sql := format($_$      
WITH RECURSIVE search_graph(        
  c1,     -- point 1        
  c2,     -- point 2        
  prop,   -- current edge property      
  all_prop,  -- properties of all edges  
  depth,  -- current depth, starting from 1         
  path    -- path, stored as an array         
) AS (        
        select c1,c2,prop,all_prop,depth,path from (        
        SELECT                               -- ROOT node query        
          g.c1,                              -- point 1        
          g.c2,                              -- point 2        
          g.prop,                            -- edge property        
      g.prop::text as all_prop,          -- properties of all edges  
          1 depth,                           -- initial depth=1        
          ARRAY[g.c1, g.c2] path             -- initial path        
        FROM tbl_er AS g         
        WHERE         
          c1 = %s                            -- ROOT node=?        
          limit %s                           -- How many records are limited at each tier?        
        ) t        
      UNION ALL        
        select c1,c2,prop,all_prop,depth,path from (        
        SELECT                               -- recursive clause         
          g.c1,                              -- point 1        
          g.c2,                              -- point 2        
          g.prop,                            -- edge property     
      sg.all_prop || g.prop::text as all_prop,    -- properties of all edges  
          sg.depth + 1 depth,                   -- depth +1        
          sg.path || g.c2 path                 -- Add a new point to the path        
        FROM tbl_er AS g, search_graph AS sg    -- circular INNER JOIN        
        WHERE         
          g.c1 = sg.c2                       -- recursive JOIN condition        
          AND (g.c2 <> ALL(sg.path))                      -- Prevent loop, determine whether it is a loop and judge if the new point is already in the previous path   
          AND sg.depth <= %s                 -- search depth =?          
          limit %s                           -- How many records are limited at each tier?       
        ) t        
)        
SELECT path as o_path, c1 as o_point1, c2 as o_point2, prop as o_link_prop, all_prop as o_link_prop_all, depth as o_depth      
FROM search_graph;                           -- query a recursive table. You can add LIMIT output or use a cursor       
$_$, i_root, i_limit, i_depth, i_limit      
);      
      
return query execute sql;      
      
end;      

$$
 language plpgsql strict;   
"""

cur.execute(sql)

# %%
conn.commit()

# %%
# %%time
sql = "select * from graph_search1(1)"
df = sqlio.read_sql_query(sql, conn)
# Out:
# CPU times: user 2.55 ms, sys: 1.57 ms, total: 4.11 ms
# Wall time: 12.6 ms

# %%
sql = "select * from graph_search1(1)"
df = sqlio.read_sql_query(sql, conn)

# %%
df.head()
# Out:
#       o_path  o_point1  o_point2 o_link_prop o_link_prop_all  o_depth
# 0     [1, 2]         1         2         [1]             {1}        1
# 1     [1, 3]         1         3         [1]             {1}        1
# 2     [1, 4]         1         4         [2]             {2}        1
# 3     [1, 7]         1         7         [2]             {2}        1
# 4  [1, 2, 5]         2         5         [2]          {1}{2}        2

# %%
df_links = sqlio.read_sql_query("select * from tbl_er_desc", conn)
df_links.head()
# Out:
#    id              info
# 0   1       has purpose
# 1   2  based on purpose
# 2   3     has attribute
# 3   4      attribute of

# %%
df_nodes = sqlio.read_sql_query("select * from tbl_detail", conn)
#df_nodes['name'] = df_nodes['info'].apply(lambda x : x['name'])
#df_nodes[['id', 'name']].head()

# %%
df_nodes.head(500)
# Out:
#       id                                               info  \
# 0      1  {'name': 'ALDERSPENSJON', 'type': 'prosessing ...
# 1      2  {'name': 'ARBEIDSAVKLARINGSPENGER (AAP)', 'typ...
# 2      3  {'name': 'AVTALEFESTET PENSJON (AFP) FOR PRIVA...
# 3      4  {'name': 'AVTALEFESTET PENSJON (AFP) FOR STATL...
# 4      5  {'name': 'BARNEBIDRAG', 'type': 'prosessing ac...
# 5      6  {'name': 'BARNETRYGD', 'type': 'prosessing act...
# 6      7  {'name': 'BIDRAGSFORSKUDD', 'type': 'prosessin...
# 7      8  {'name': 'DAGPENGER', 'type': 'prosessing acti...
# 8      9  {'name': 'EKTEFELLEBIDRAG', 'type': 'prosessin...
# 9     10  {'name': 'ETTERLATTEPENSJON OG BARNEPENSJON', ...
# 10    11  {'name': 'FARSKAP OG MORSKAP', 'type': 'proses...
# 11    12  {'name': 'FORELDREPENGER, ENGANGSTØNAD OG SVAN...
# 12    13  {'name': 'FORSIKRING', 'type': 'prosessing act...
# 13    14  {'name': 'FORVALTNING AV AA-REGISTERET', 'type...
# 14    15  {'name': 'FRIVILLIG YRKESSKADETRYGD', 'type': ...
# 15    16  {'name': 'GRAVFERDSSTØNAD OG STØNAD TIL BÅRETR...
# 16    17  {'name': 'GRUNN- OG HJELPESTØNAD', 'type': 'pr...
# 17    18  {'name': 'KONTANTSTØTTE', 'type': 'prosessing ...
# 18    19  {'name': 'KONTROLL', 'type': 'prosessing activ...
# 19    20  {'name': 'KRIGSPENSJON', 'type': 'prosessing a...
# 20    21  {'name': 'LØNNSGARANTI', 'type': 'prosessing a...
# 21    22  {'name': 'MEDLEMSKAP OG AVGIFT', 'type': 'pros...
# 22    23  {'name': 'MENERSTATNING', 'type': 'prosessing ...
# 23    24  {'name': 'OMSORGSOPPTJENING', 'type': 'prosess...
# 24    25  {'name': 'OPPFOSTRINGSBIDRAG', 'type': 'proses...
# 25    26  {'name': 'PLEIE-, OMSORGS- OG OPPLÆRINGSPENGER...
# 26    27  {'name': 'REKVIRERING AV D-NUMMER', 'type': 'p...
# 27    28  {'name': 'SIMULERING - AVTALEFESTET PENSJON (A...
# 28    29  {'name': 'STØNAD TIL ENSLIG MOR ELLER FAR', 't...
# 29    30  {'name': 'SUPPLERENDE STØNAD', 'type': 'proses...
# ..   ...                                                ...
# 189  190  {"name":Folketrygdloven, Lov om sosiale tjenes...
# 190  191  {"name":Alle ytelser etter ftrl, btrl, kontant...
# 191  192  {"name":Forvaltningsloven § 12, "type": "legal...
# 192  193       {"name":Ftrl. § 22-1, "type": "legal_basis"}
# 193  194  {"name":Taushetsplikten, Forvaltningsloven § 1...
# 194  195  {"name":§ 22-1 og taushetsplikt, "type": "lega...
# 195  196  {"name":Kap 8. § 22-1, 22-13 og 22-15, taushet...
# 196  197          {"name":Fvl § 12 , "type": "legal_basis"}
# 197  198  {"name":Det legges til grunn at Lgl + Lgf kapi...
# 198  199  {'name': 'Sivilstand', 'type': 'attribute', 'd...
# 199  200  {'name': 'Arbeidsforhold', 'type': 'attribute'...
# 200  201  {'name': 'Kjønn', 'type': 'attribute', 'descri...
# 201  202  {'name': 'Navn', 'type': 'attribute', 'descrip...
# 202  203  {'name': 'Fødselsdato ', 'type': 'attribute', ...
# 203  204  {'name': 'Fødselsnummer ', 'type': 'attribute'...
# 204  205  {'name': 'Bostedsadresse i Norge', 'type': 'at...
# 205  206  {'name': 'Bostedsadresse i utlandet', 'type': ...
# 206  207  {'name': 'Arbeidstillatelse ', 'type': 'attrib...
# 207  208  {'name': 'Adopsjon ', 'type': 'attribute', 'de...
# 208  209  {'name': 'Barn', 'type': 'attribute', 'descrip...
# 209  210  {'name': 'Daglig omsorg ', 'type': 'attribute'...
# 210  211  {'name': 'Delt bosted ', 'type': 'attribute', ...
# 211  212  {'name': 'e-post', 'type': 'attribute', 'descr...
# 212  213  {'name': 'Farskap', 'type': 'attribute', 'desc...
# 213  214  {'name': 'Flerfødsel', 'type': 'attribute', 'd...
# 214  215  {'name': 'Flyktningstatus ', 'type': 'attribut...
# 215  216  {'name': 'Foreldreansvar', 'type': 'attribute'...
# 216  217  {'name': 'Forsterforeldre ', 'type': 'attribut...
# 217  218  {'name': 'Fullmakt ', 'type': 'attribute', 'de...
# 218  219  {'name': 'NOT AVAILABLE', 'type': 'attribute',...
#
#                       crt_time
# 0   2019-10-07 17:43:49.778671
# 1   2019-10-07 17:43:49.778671
# 2   2019-10-07 17:43:49.778671
# 3   2019-10-07 17:43:49.778671
# 4   2019-10-07 17:43:49.778671
# 5   2019-10-07 17:43:49.778671
# 6   2019-10-07 17:43:49.778671
# 7   2019-10-07 17:43:49.778671
# 8   2019-10-07 17:43:49.778671
# 9   2019-10-07 17:43:49.778671
# 10  2019-10-07 17:43:49.778671
# 11  2019-10-07 17:43:49.778671
# 12  2019-10-07 17:43:49.778671
# 13  2019-10-07 17:43:49.778671
# 14  2019-10-07 17:43:49.778671
# 15  2019-10-07 17:43:49.778671
# 16  2019-10-07 17:43:49.778671
# 17  2019-10-07 17:43:49.778671
# 18  2019-10-07 17:43:49.778671
# 19  2019-10-07 17:43:49.778671
# 20  2019-10-07 17:43:49.778671
# 21  2019-10-07 17:43:49.778671
# 22  2019-10-07 17:43:49.778671
# 23  2019-10-07 17:43:49.778671
# 24  2019-10-07 17:43:49.778671
# 25  2019-10-07 17:43:49.778671
# 26  2019-10-07 17:43:49.778671
# 27  2019-10-07 17:43:49.778671
# 28  2019-10-07 17:43:49.778671
# 29  2019-10-07 17:43:49.778671
# ..                         ...
# 189 2019-10-07 17:43:57.154261
# 190 2019-10-07 17:43:57.154261
# 191 2019-10-07 17:43:57.154261
# 192 2019-10-07 17:43:57.154261
# 193 2019-10-07 17:43:57.154261
# 194 2019-10-07 17:43:57.154261
# 195 2019-10-07 17:43:57.154261
# 196 2019-10-07 17:43:57.154261
# 197 2019-10-07 17:43:57.154261
# 198 2019-10-07 17:45:40.436798
# 199 2019-10-07 17:45:40.436798
# 200 2019-10-07 17:45:40.436798
# 201 2019-10-07 17:45:40.436798
# 202 2019-10-07 17:45:40.436798
# 203 2019-10-07 17:45:40.436798
# 204 2019-10-07 17:45:40.436798
# 205 2019-10-07 17:45:40.436798
# 206 2019-10-07 17:45:40.436798
# 207 2019-10-07 17:45:40.436798
# 208 2019-10-07 17:45:40.436798
# 209 2019-10-07 17:45:40.436798
# 210 2019-10-07 17:45:40.436798
# 211 2019-10-07 17:45:40.436798
# 212 2019-10-07 17:45:40.436798
# 213 2019-10-07 17:45:40.436798
# 214 2019-10-07 17:45:40.436798
# 215 2019-10-07 17:45:40.436798
# 216 2019-10-07 17:45:40.436798
# 217 2019-10-07 17:45:40.436798
# 218 2019-10-07 17:45:40.436798
#
# [219 rows x 3 columns]

# %%
df_edgelist=df[['o_point1','o_point2','o_link_prop','o_depth']].copy()
df_edgelist.columns=['source','target','id','weight']
df_edgelist['id'] = df_edgelist['id'].apply(lambda x: x[0])
df_edgelist = pd.merge(df_edgelist, df_links, on='id', how='left')
df_edgelist = pd.merge(df_edgelist, df_nodes[['id', 'name']], left_on='source', right_on='id')
df_edgelist = pd.merge(df_edgelist, df_nodes[['id', 'name']], left_on='target', right_on='id')
#df_edgelist = df_edgelist[['info', 'name_x', 'name_y','id','weight']]
#df_edgelist.columns = ['name', 'source', 'target','id','weight']
df_edgelist.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-fe3882785e01> in <module>
# ----> 1 df_edgelist=df[['o_point1','o_point2','o_link_prop','o_depth']].copy()
#       2 df_edgelist.columns=['source','target','id','weight']
#       3 df_edgelist['id'] = df_edgelist['id'].apply(lambda x: x[0])
#       4 df_edgelist = pd.merge(df_edgelist, df_links, on='id', how='left')
#       5 df_edgelist = pd.merge(df_edgelist, df_nodes[['id', 'name']], left_on='source', right_on='id')
#
# ~/anaconda3/envs/dv/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~/anaconda3/envs/dv/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# ~/anaconda3/envs/dv/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# ~/anaconda3/envs/dv/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1244                 raise KeyError(
#    1245                     u"None of [{key}] are in the [{axis}]".format(
# -> 1246                         key=key, axis=self.obj._get_axis_name(axis)))
#    1247
#    1248             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['o_point1', 'o_point2', 'o_link_prop', 'o_depth'], dtype='object')] are in the [columns]"

# %%
import altair as alt
alt.renderers.enable('notebook')
alt.themes.enable('opaque')
import networkx as nx
import nx_altair as nxa
import numpy as np

G = nx.from_pandas_edgelist(df_edgelist, 'source', 'target', ['name','id','weight'])
pos = nx.spring_layout(G)

# %%
nx.draw_networkx(
    G=G,
    pos=pos
)

# %%
# Compute positions for viz.
pos = nx.spring_layout(G)

viz = nxa.draw_networkx(
    G, pos=pos,
    node_color='id:N',
    cmap='viridis',
    width='weight:N',
    edge_color='black',
    node_tooltip=['weight:N']
)

viz.interactive()
